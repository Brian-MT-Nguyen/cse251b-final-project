# %%
import matplotlib.pyplot as plt


x = list(range(1, 11))
y = [0.1026,0.0528,0.0516,0.0473,0.0490,0.0451,0.0453,0.0418,0.0434,0.0437]

plt.plot(x, y, label="MLP Model")
plt.title("MLP Model Training Loss vs Epoch")
plt.xlabel("Epoch Iteration Number")
plt.ylabel("Training Loss (Normalized)")
# Out:
# Text(0, 0.5, 'Training Loss (Normalized)')

# %%
import matplotlib.pyplot as plt


x = list(range(1, 11))
y = [0.1026,0.0528,0.0516,0.0473,0.0490,0.0451,0.0453,0.0418,0.0434,0.0437]

plt.plot(x, y, label="MLP Model")
plt.title("Training Loss vs Epoch")
plt.xlabel("Epoch Iteration Number")
plt.ylabel("Training Loss (Normalized)")

x = list(range(1, 11))
y = [0.8300,0.7173,0.7146,0.7070,0.6869,0.6154,0.5393,0.4977,0.4538,0.2965]

plt.plot(x, y, label="LSTM Model")
plt.xlabel("Epoch Iteration Number")
plt.ylabel("MAE Training Loss (Normalized)")
plt.legend()
